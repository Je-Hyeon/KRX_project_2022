# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re
import random
import tqdm
from tqdm.contrib import tzip

# %%
# 전처리를 위한 함수 구현
def replacer(text, input):
    for garbage in input:
        text = text.replace(garbage, "")
    return text

# %%
class KIND_REPORTS:
    __kind_url = "https://kind.krx.co.kr/disclosure/details.do"
    __kind_header = {
        'authority': 'kind.krx.co.kr',
        'method': 'POST',
        'path': '/disclosure/details.do',
        'scheme': 'https',
        'accept': 'text/html, */*; q=0.01',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
        'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'origin': 'https://kind.krx.co.kr',
        'referer': 'https://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain',
        'sec-ch-ua': """"Google Chrome";v="105", "Not)A;Brand";v="8", "Chromium";v="105""""",
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': "Windows",
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest'
    }
    __kind_params ={
        'method': 'searchDetailsSub',
        'currentPageSize': '100',
        'pageIndex': '1',
        'orderMode': '1',
        'orderStat': 'D',
        'forward': 'details_sub',
        'disclosureType01': '',
        'disclosureType02': '',
        'disclosureType03': '',
        'disclosureType04': '',
        'disclosureType05': '',
        'disclosureType06': '',
        'disclosureType07': '',
        'disclosureType08': '',
        'disclosureType09': '',
        'disclosureType10': '',
        'disclosureType11': '',
        'disclosureType13': '',
        'disclosureType14': '',
        'disclosureType20': '',
        'pDisclosureType01': '',
        'pDisclosureType02': '',
        'pDisclosureType03': '',
        'pDisclosureType04': '',
        'pDisclosureType05': '',
        'pDisclosureType06': '',
        'pDisclosureType07': '',
        'pDisclosureType08': '',
        'pDisclosureType09': '',
        'pDisclosureType10': '',
        'pDisclosureType11': '',
        'pDisclosureType13': '',
        'pDisclosureType14': '',
        'pDisclosureType20': '',
        'searchCodeType': '',
        'repIsuSrtCd': '',
        'allRepIsuSrtCd': '',
        'oldSearchCorpName': '',
        'disclosureType': '',
        'disTypevalue': '',
        'reportNm': '',
        'reportCd': '',
        'searchCorpName': '',
        'business': '',
        'marketType': '',
        'settlementMonth': '',
        'securities': '',
        'submitOblgNm': '',
        'enterprise': '',
        'fromDate': '2',
        'toDate': '',
        'reportNmTemp': '',
        'reportNmPop': '',
        'bfrDsclsType': 'on'
    }

    def __init__(self):
        self.__sleep_min = 0.2
        self.__sleep_max = 0.5
        self.report_list = []
        self.report_content = []
        pass
    
    def __isResultExist(self, what_result):
        if len(what_result) != 0:
            print("Warning! Previous "+ str(what_result)+" remains")
            answer = input("Do you want to continue and replace the result? [y/n] :")
            if answer == 'y':
                pass
            else:
                raise Exception("Process closed")
        else:
            pass

    def set_sleep(self, min=0.2, max=0.5):
        self.__sleep_min = min
        self.__sleep_max = max
    
    def get_list(self, report, start, end, market_type, submit_by=""):
        '''
        marker_type = 1 : 코스피, 2 코스닥 / 검색어는 report에 입력
        '''
        self.__isResultExist(self.report_list)
        self.market_type = market_type
        params = self.__kind_params   # __kind_params 인수를 복제해서 사용
        params['reportNm'] = report
        params['fromDate'] = start
        params['toDate'] = end
        params['marketType'] = market_type
        params['reportNmTemp'] = report

        if submit_by == 'krx':
            submit_by = "유가증권시장본부"
        params['submitOblgNm'] = submit_by
        res = requests.post(self.__kind_url, headers=self.__kind_header, data=params) # 쿼리 날려요
        bs = BeautifulSoup(res.text, 'html.parser')

        end_page_loc = str(bs).find('</strong>/')
        page_length = int(str(bs)[end_page_loc+len('</strong>/'):end_page_loc+str(bs)[end_page_loc:].find('\xa0')])

        report_date = []
        company_name = []
        report_code = []
        report_name = []
        isCorrection = []

        for i in tqdm.tqdm(range(page_length)):
            time.sleep(random.uniform(self.__sleep_min, self.__sleep_max))
            params['pageIndex'] = str(i+1)
            res = requests.post(self.__kind_url, headers=self.__kind_header, data=params) # 쿼리 날려요
            bs = BeautifulSoup(res.text, 'html.parser')

            tags = bs.find_all("a")

            for tag in tags:
                if tag.get('href') == "#companysum":
                    company_name.append(tag.get('title'))

                elif tag.get('href') == "#viewer":
                    tmp_code = re.findall(r'\d+', str(tag.get('onclick')))[0]
                    report_code.append(tmp_code)
                    report_date.append(tmp_code[:4]+'-'+tmp_code[4:6]+'-'+tmp_code[6:8])                
                    report_name.append(tag.get('title'))

                    if '정정' in str(tag):
                        isCorrection.append('YES')
                    else:
                        isCorrection.append('NO')

        self.report_list = pd.DataFrame([report_date,company_name,report_code,report_name,isCorrection]).T
        self.report_list.columns = ['공시일','회사명','코드','보고서명','정정신고']
        # 자회사인 경우는 drop
        self.report_list = self.report_list.loc[~self.report_list["보고서명"].str.contains("자회사"), :].reset_index(drop=True)

        #if report == '상호변경':
        #    self.report_list = self.report_list.loc[(self.report_list['보고서명'] == '상호변경안내') | (self.report_list['보고서명'] == '변경상장(상호변경)')]
        #    self.report_list.reset_index(drop=True)

        # 회사명이 None인 경우를 해결해보자
        if self.report_list['회사명'].isnull().sum() >= 1:
            df_null = self.report_list.loc[self.report_list['회사명'].isnull()]
            index_list = df_null.index
            date_list = df_null['공시일'].values
            report_l = df_null['보고서명'].values

            find_name = []
            for date, r in zip(date_list, report_l):
                name_tag = self.__find_none(report = r, start=date,end = date, market_type=market_type)
                find_name.append(name_tag)
            
            for indx, name in zip(index_list, find_name):
                self.report_list['회사명'].loc[indx] = name
        print()
        print('Jobs Done')
        print('check the result with .report_list')
    
    # v6에서 추가
    def __find_none(self, report, start, end, market_type, submit_by=""):

        if len(report) > 6:
            report = report[:5]  #띄어쓰기는 검색이 안되는 오류를 잡기 위해서 추가

        params = self.__kind_params   # __kind_params 인수를 복제해서 사용
        params['reportNm'] = report
        params['fromDate'] = start
        params['toDate'] = end
        params['marketType'] = market_type
        params['reportNmTemp'] = report
        
        if submit_by == 'krx':
            submit_by = "유가증권시장본부"
        params['submitOblgNm'] = submit_by
        res = requests.post(self.__kind_url, headers=self.__kind_header, data=params) # 쿼리 날려요
        bs = BeautifulSoup(res.text, 'html.parser')
        tag = bs.a
        tag = tag.text.replace(' ', '')  # tag가 해당 회사 이름이 된다
        return tag

    def __engine_read_report(self, doc):
        url = "https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=" + doc + "&docno=&viewerhost=&viewerport="
        res = requests.get(url) # 쿼리 날려요
        bs = BeautifulSoup(res.text, 'html.parser')
        
        # 기업공시코드를 찾는다
        h1_tag = bs.find_all("h1")[0]
        company_code = re.findall(r"\d{6,6}", str(h1_tag))[0]

        # url을 찾는다
        option_tag = bs.find_all("option")
        select_str = ''

        for tag in option_tag:
            if str(tag).startswith('<option selected="selected"'):
                select_str = str(tag)
                if "[정정]" in select_str:
                    return ('No','No','No', 'No') #정정공시일 경우에는 읽지 않는다(기존공시의 부수로 읽을 거기 때문에)
                else:
                    new_doc = re.findall(r'\d{6,}', str(option_tag))
                    doc_code = None  # 현재 읽은 공시의 코드를 리턴한다

                    url = "https://kind.krx.co.kr/common/disclsviewer.do?method=searchContents&docNo=" + str(new_doc[0]) #최초의 공시로 쿼리
                    doc_code = new_doc[0]
                    after_list = new_doc[1:] # 쿼리를 날린 0번째를 제외한 나머지를    

                    res = requests.get(url) # 쿼리 날려요
                    bs = str(BeautifulSoup(res.text, 'html.parser'))

                    inner_url = re.findall('https://[a-z0-9/.]+\.htm', bs)[0] #v7코드개선
                    res = requests.get(inner_url) # 쿼리 날려요
                    html = res.content.decode('utf-8','replace')
                    bs = BeautifulSoup(html, 'html.parser')

                    text_only_list = []

                    ######################여기부분 수정#############
                    if (self.read_what == 'right_issue') and (self.market_type =='1'):
                        a = bs.find_all("pre")[0].get_text()
                        a = a.replace('\n',' : ')
                        text = re.split(r"[①②③④⑤⑥]", a)
                        #text = a.split("") # 띄어쓰기 하나 수정?
                        return text, after_list, doc_code, company_code
                    ###############################################


                #    if self.read_what == 'sales':
                #        text_only_list.append([tag.get_text() for tag in bs.find_all('span')])
#
                    else: #유상증자인 경우 코스닥은 여기로?
                        if '▶ 업종코드 :' not in str(bs):
                            tags = bs.find_all('td')
                            for tag in tags:
                                text = tag.get_text()
                                text = text.replace('\r\n', ', ')
                                text = replacer(text, [", \n","\r",'\n'])
                                text_only_list.append(text)
                        elif '▶ 업종코드 :' in str(bs): # 유가증권시장본부가 공시하는 '변경상장(상호변경)'
                            text = replacer(bs.get_text(), [", \n","\r",'\n','   → ','- '])
                            text = text.split('    ')

                            if len(text) <=4:
                                return "No","No","No","No"

                            text_only_list = text_only_list + replacer(text[3], ['(영문명',')','보통주','우선주']).split(': ')
                            text_only_list = text_only_list + replacer(text[5], ['(영문명',')','보통주','우선주']).split(': ')

                    if len(after_list) <=0:
                        after_list = '없음' 

                    return text_only_list, after_list, doc_code, company_code # after_list는 이후 정정된 공시코드 리스트임 / doc_code는 지금 읽은 공시의 코드
    
    # v7 추가
    def __doc_filter(self, doc_list):    # 필터 기업코드 찾는 걸로 손봐야한다
        '''정정된 공시를 제외한 첫번째 공시만 읽어온다'''
        self.__isResultExist(self.report_content)
        self.read_what = 'filter'

        announce_date = doc_list['공시일'].values
        name_ar = doc_list['회사명'].values
        code_ar = doc_list['코드'].values
        report_list = doc_list['보고서명'].values
        rereport_list = doc_list['정정신고'].values

        preprocessed_data = []

        for code, name, date, report, rereport in tzip(code_ar, name_ar, announce_date, report_list, rereport_list):
            time.sleep(random.uniform(self.__sleep_min, self.__sleep_max))
            url = "https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=" + code + "&docno=&viewerhost=&viewerport="
            res = requests.get(url) # 쿼리 날려요
            bs = BeautifulSoup(res.text, 'html.parser')
            option_tag = bs.find_all("option")
            select_str = ''

            for tag in option_tag:
                if str(tag).startswith('<option selected="selected"'):
                    select_str = str(tag)
                    if "[정정]" in select_str:
                        continue #정정공시일 경우에는 읽지 않는다(기존공시의 부수로 읽을 거기 때문에)
                    preprocessed_data.append([date, name, code, report, rereport])

        return pd.DataFrame(preprocessed_data, columns=["공시일","회사명","코드","보고서명","정정신고"])
    
    def read_right_issue(self, doc_list):   # 아직 미구현임!!!
        '''(v7수정사항) 좀 더 정확한 "추가상장 유상증자" 검색어를 입력해야 한다'''
        self.__isResultExist(self.report_content)
        self.read_what = 'right_issue'
        
        code_ar = doc_list['코드'].values
        name_ar = doc_list["회사명"].values
        announce_date = doc_list["공시일"].values
        report_name = doc_list["보고서명"].values

        preprocessed_data = []

        for code, name, date,report_n in tzip(code_ar, name_ar, announce_date, report_name):
            time.sleep(random.uniform(self.__sleep_min, self.__sleep_max))
            text_only_list, after_list, now_code, company_code = self.__engine_read_report(code) # 쿼리 날려요 두번 날려요
            list_of_corp = []

            if (text_only_list == 'No') or (text_only_list == []): # 정정공시일 경우에는 None을 리턴해서 SKIP
                continue
            
            if self.market_type == '1': #코스피
                print(name,date,report_n,"진행중.....")
                print(text_only_list)

                tmp_return = text_only_list[1]
                price = text_only_list[2]
                how = text_only_list[5]
                #how = re.findall('\(([^)]+\))', report_n)[0]
                #how = re.findall('\(([^)]+)', how)[0]
                list_of_corp.extend([name,company_code,date,tmp_return,price,how])

            else:   #코스닥인 경우
                print(text_only_list)
                list_of_corp.extend([name,company_code, date, text_only_list[-4], text_only_list[6],text_only_list[-3], text_only_list[-2]])

            #preprocessed_data.append(list_of_corp)
            
       # self.report_content = pd.DataFrame(preprocessed_data, columns=['회사명','기업공시코드','공시일',"임시리턴", '발행가(원)', "발행방법"])
        print()
        print('Jobs Done')
        print('check the result with .report_content')

# %%
# 검색어 : [단일판매ㆍ공급계약체결 / 업종변경 / 상호변경 / 추가상장 유상증자 /전환사채권발행결정 / 신주인수권부사채권발행결정/투자주의환기종목지정 / 최대주주변경 / 불성실공시법인지정/조회공시요구/타법인주식및출자증권취득결정]
test20 = KIND_REPORTS()
test20.get_list('추가상장 유상증자', start='2022-01-01', end='2022-12-31', market_type='2')
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Jobs Done
# check the result with .report_list

# %%
test20.report_list.head()#.loc[test20.report_list["보고서명"] == "유상증자결정(제3자배정-철회)"]
# Out:
#           공시일     회사명              코드               보고서명 정정신고
# 0  2022-12-29  수성샐바시온  20221229000948  추가상장(유상증자(제3자배정))   NO
# 1  2022-12-29     위지트  20221229000860  추가상장(유상증자(제3자배정))   NO
# 2  2022-12-28     MIT  20221228000924   추가상장(유상증자(출자전환))   NO
# 3  2022-12-22     피씨엘  20221222000648   추가상장(유상증자-제3자배정)   NO
# 4  2022-12-20     HLB  20221220000412  추가상장(유상증자(구주주배정))   NO

# %%
test20.read_right_issue(test20.report_list)
# Out:
#   0%|          | 0/110 [00:00<?, ?it/s]
# ['1.회사명', '(주)이브이수성', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A084180', '7,722,777', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '71,264,362', '2022-01-01', '5.상장일', '2023-01-02', '6.기타', 'ㅇ 의무보유 내역,   - 대상주식수 : 7,722,777주,   - 대상기간 : 2023.01.02 ~ 2024.01.01', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '7,722,777', '1,295', "제26회('22.12.14)"]
# ['1.회사명', '(주)위지트', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A036090', '5,039,370', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '102,976,202', '2022-01-01', '5.상장일', '2023-01-02', '6.기타', 'ㅇ 의무보유내역,  - 대상주식수 : 5,039,370주,  - 대상기간 : 2023.01.02 ~ 2024.01.01', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '5,039,370', '635', "제29회('22.12.15)"]
# ['1.회사명', '(주)유씨아이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A038340', '7,679,860', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '13,910,019', '2022-01-01', '5.상장일', '2022-12-29', '6.기타', 'ㅇ 의무보유내역,  - 대상주식수 : 898,376주(감자 반영시 112,297주),  - 대상기간 : 2022.12.29 ~ 2023.06.28', '【발행내역】', '보통주', '유상증자(출자전환)', '제3자배정', '7,679,860', '500', "제55회('22.09.19)"]
# ['1.회사명', '피씨엘(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A241820', '1,163,555', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '11,732,753', '2022-01-01', '5.상장일', '2022-12-23', '6.기타', "* 의무보유에 관한 사항,  - 의무보유주식수 : 1,163,555주,  - 의무보유기간 : '22.12.23~'23.12.22 (1년)", '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,163,555', '10,365', "제14회('22.12.13)"]
# ['1.회사명', '에이치엘비(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A028300', '9,562,408', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '116,465,889', '2022-01-01', '5.상장일', '2022-12-23', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정', '9,562,408', '25,200', "제86회('22.12.10)"]
# ['1.회사명', '(주)에스디시스템', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A121890', '1,538,460', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '12,686,120', '2022-01-01', '5.상장일', '2022-12-19', '6.기타', 'ㅇ 의무보유내역,  - 대상주식수 : 1,538,460주,  - 대상기간 : 2022.12.19 ~ 2023.12.18', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,538,460', '650', "제8회('22.11.29)"]
# ['1.회사명', '커머스마이너 주식회사', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A223310', '418,235', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '15,730,371', '2022-01-01', '5.상장일', '2022-12-14', '6.기타', 'ㅇ 의무보유 내역,  - 대상주식수 : 418,235주,  - 대상기간 : 2022.12.14 ~ 2023.12.13', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '418,235', '2,391', "제29회('22.11.29)"]
# ['1.회사명', '(주)형지아이앤씨', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A011080', '12,498,814', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '25,503,363', '2022-01-01', '5.상장일', '2022-12-15', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정', '12,498,814', '1,440', "제12회('22.12.03)"]
# ['1.회사명', '스튜디오드래곤(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A253450', '44,313', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '30,058,498', '2022-01-01', '5.상장일', '2022-12-06', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 44,313주(전량),   - 대상기간 : 2022.12.06 ~ 2023.12.05', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '44,313', '67,700', "제11회('22.11.17)"]
# ['1.회사명', '크리스탈지노믹스(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A083790', '1,500,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '70,746,486', '2022-01-01', '5.상장일', '2022-11-28', '6.기타', 'ㅇ의무보유 내역,  - 대상주식수 : 1,500,000주,  - 대상기간 : 2022.11.28~2023.11.27', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,500,000', '3,805', "제65회('22.11.12)"]
# ['1.회사명', '(주)오스코텍', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A039200', '6,400,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '36,606,525', '2022-01-01', '5.상장일', '2022-11-30', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '6,400,000', '13,850', "제30회('22.11.16)"]
# ['1.회사명', '(주)더블유아이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A073570', '50,000,000', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '133,312,228', '2022-01-01', '5.상장일', '2022-11-18', '6.기타', '* 의무보유 관련 사항, - 기간 : 2022.11.18 ~ 2023.11.17, - 주식 : 50,000,000주', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '50,000,000', '811', "제40회('22.11.01)"]
# ['1.회사명', '(주)알파홀딩스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A117670', '1,000,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '27,917,635', '2022-01-01', '5.상장일', '2022-11-17', '6.기타', 'ㅇ 의무보유에 관한 사항,  - 의무보유수량 : 1,000,000주,  - 의무보유기간 : 2022.11.17 ~ 2023.11.16', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,000,000', '1,225', "제19회('22.10.21)"]
# ['1.회사명', '(주)에이티세미콘', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A089530', '10,095,368', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '67,246,469', '2022-01-01', '5.상장일', '2022-11-16', '6.기타', 'ㅇ 의무보유에 관한 사항,  - 의무보유수량 : 10,095,368주,  - 의무보유기간 : 2022.11.16 ~ 2023.11.15', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '10,095,368', '1,002', "제36회('22.10.28)"]
# ['1.회사명', '(주)에이팩트', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A200470', '10,244,988', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '28,721,177', '2022-01-01', '5.상장일', '2022-11-15', '6.기타', "ㅇ 의무보유에 관한 사항,  - 의무보유수량 : 10,244,988주,  - 의무보유기간 : '22.11.15 ~ '23.11.14 ", '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '10,244,988', '4,490', "제5회('22.10.28)"]
# ['1.회사명', '(주)코센', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A009730', '5,509,921', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '25,190,018', '2022-01-01', '5.상장일', '2022-11-09', '6.기타', 'ㅇ 의무보유에 관한 사항,  - 의무보유주식수 : 5,509,921주,  - 의무보유기간 : 2022.11.09 ~ 2023.11.08', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '5,509,921', '1,280', "제42회('22.10.29)"]
# ['1.회사명', '(주)더블유아이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A073570', '597,014', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '83,312,228', '2022-01-01', '5.상장일', '2022-11-11', '6.기타', '-', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '597,014', '1,675', "제39회('22.10.07)"]
# ['1.회사명', '(주)하이드로리튬', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A101670', '3,083,701', '3.1주당 액면가/자본금(원)', '200', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '22,333,351', '2022-01-01', '5.상장일', '2022-11-07', '6.기타', 'ㅇ 의무보유 내역,   - 대상주식수 : 3,083,701주,   - 대상기간 : 2022.11.07~2023.11.06', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '3,083,701', '2,270', "제7회('22.10.20)"]
# ['1.회사명', '(주)이엠앤아이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A083470', '350,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '20,538,618', '2022-01-01', '5.상장일', '2022-11-07', '6.기타', 'ㅇ 우리사주조합 의무예탁에 관한 사항,   - 대상주식수 : 350,000주,   - 대상기간 : 2022.11.07 ~ 2023.11.06 ', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '350,000', '1,000', "제30회('22.10.22)"]
# ['1.회사명', '오가닉티코스메틱스홀딩스컴퍼니리미티드', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A900300', '40,000,000', '3.1주당 액면가/자본금(CNY)', '-', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '166,552,480', '2022-01-01', '5.상장일', '2022-11-03', '6.기타', 'ㅇ 의무보유 내역,   - 대상주식수 : 40,000,000주,   - 대상기간 : 2022.11.03~2023.11.02', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '40,000,000', '500', "제9회('22.07.15)"]
# ['1.회사명', '(주)에스디생명공학', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A217480', '19,000,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '41,415,066', '2022-01-01', '5.상장일', '2022-11-03', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '19,000,000', '1,815', "제16회('22.10.21)"]
# ['1.회사명', '(주)퓨쳐켐', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A220100', '3,310,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '17,001,971', '2022-01-01', '5.상장일', '2022-11-03', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '3,310,000', '9,390', "제21회('22.10.21)"]
# ['1.회사명', '(주)윈팩', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A097800', '9,917,355', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '59,584,496', '2022-01-01', '5.상장일', '2022-10-31', '6.기타', 'ㅇ 의무보유내역,  - 대상주식수 : 9,917,355주,  - 대상기간 : 2022.10.31 ~ 2023.10.30', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '9,917,355', '1,210', "제14회('22.10.18)"]
# ['1.회사명', '(주)지앤비에스엔지니어링', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A382800', '287,625', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '7,478,243', '2022-01-01', '5.상장일', '2022-10-28', '6.기타', 'ㅇ 의무보유내역,  - 대상주식수 : 287,625주,  - 대상기간 : 2022.10.28 ~ 2023.10.27', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '287,625', '11,850', "제5회('22.10.15)"]
# ['1.회사명', '(주)이엠앤아이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A083470', '1,210,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '20,188,618', '2022-01-01', '5.상장일', '2022-10-13', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 1,210,000주,   - 대상기간 : 2022.10.13~2023.10.12 (1년)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,210,000', '1,000', "제29회('22.09.22)"]
# ['1.회사명', '(주)오비고', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A352910', '602,675', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '12,053,493', '2022-01-01', '5.상장일', '2022-10-12', '6.기타', 'ㅇ 의무보유내역,  - 대상주식수 : 602,675주,  - 대상기간 : 2022.10.12 ~ 2023.10.11', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '602,675', '12,000', "제8회('22.09.24)"]
# ['1.회사명', '주식회사 파라텍', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A033540', '22,500,000', '3.1주당 액면가/자본금(원)', '200', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '73,175,379', '2022-01-01', '5.상장일', '2022-10-11', '6.기타', '-', '【발행내역】', '보통주', '유상증자(일반공모)', '일반공모', '22,500,000', '850', "제12회('22.09.28)"]
# ['1.회사명', '(주)한창바이오텍', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A043090', '6,201,550', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '43,991,293', '2022-01-01', '5.상장일', '2022-09-29', '6.기타', 'ㅇ의무보유 내역,  - 대상주식수 : 6,201,550주,  - 대상기간 : 2022.09.29~2023.09.28', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '6,201,550', '1,935', "제35회('22.09.16)"]
# ['1.회사명', '(주)셀바스에이아이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A108860', '151,285', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '22,510,260', '2022-01-01', '5.상장일', '2022-09-29', '6.기타', '-', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '151,285', '6,610', "제14회('22.09.14)"]
# ['1.회사명', '주식회사 카이노스메드', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A284620', '5,600,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '27,922,396', '2022-01-01', '5.상장일', '2022-09-28', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '5,600,000', '4,700', "제42회('22.09.17)"]
# ['1.회사명', '프레스티지바이오로직스(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A334970', '13,787,830', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '61,107,969', '2022-01-01', '5.상장일', '2022-09-22', '6.기타', 'ㅇ의무보유 내역,  - 대상주식수 : 13,787,830주,  - 대상기간 : 2022.09.22~2023.09.21', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '13,787,830', '4,342', "제11회('22.09.06)"]
# ['1.회사명', '제이스코홀딩스(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A023440', '584,795', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '36,980,864', '2022-01-01', '5.상장일', '2022-09-22', '6.기타', '-', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '584,795', '1,710', "제19회('22.09.03)"]
# ['1.회사명', '삼강엠앤티(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A100090', '14,629,747', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '53,235,012', '2022-01-01', '5.상장일', '2022-09-16', '6.기타', 'ㅇ 의무보유 내역,   - 대상주식수 : 14,629,747주,   - 대상기간 : 2022.09.16~2023.09.15', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '14,629,747', '20,000', "제11회('22.09.01)"]
# ['1.회사명', '코오롱티슈진(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', 'KDR', 'A950160', '3,970,000', '3.1주당 액면가/자본금(USD)', '-', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', 'KDR', '68,890,050', '2022-01-01', '5.상장일', '2022-09-16', '6.기타', 'o 의무보유 내용,  - 의무보유 수량 : 3,970,000 (KDR),  - 의무보유 기간 : 2022.09.16 ~ 2023.09.15 (1년)  ', '【발행내역】', 'KDR', '유상증자(제3자배정)', '제3자배정', '3,970,000', '9,773', "제11회('22.08.31)"]
# ['1.회사명', '(주)에이트원', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A230980', '1,126,126', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '63,154,559', '2022-01-01', '5.상장일', '2022-09-16', '6.기타', '-', '【발행내역】', '보통주', '유상증자(일반공모)', '일반공모', '1,126,126', '888', "제16회('22.09.03)"]
# ['1.회사명', '어보브반도체(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A102120', '321,100', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '17,780,753', '2022-01-01', '5.상장일', '2022-09-13', '6.기타', 'ㅇ의무보유 내역,  - 대상주식수 : 321,100주,  - 대상기간 : 2022.09.13~2023.09.12', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '321,100', '10,900', "제8회('22.08.26)"]
# ['1.회사명', '(주)셀바스에이아이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A108860', '303,030', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '22,358,975', '2022-01-01', '5.상장일', '2022-09-07', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 303,030주(전량),   - 대상기간 : 2022.09.07 ~ 2023.09.06', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '303,030', '6,600', "제13회('22.08.23)"]
# ['1.회사명', '(주)폴라리스세원', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A234100', '4,520,038', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '48,001,785', '2022-01-01', '5.상장일', '2022-09-07', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 4,520,038주(전량),   - 대상기간 : 2022.09.07 ~ 2023.09.06', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '4,520,038', '2,146', "제10회('22.08.25)"]
# ['1.회사명', '(주)에이티세미콘', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A089530', '6,310,679', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '57,151,101', '2022-01-01', '5.상장일', '2022-09-05', '6.기타', "ㅇ 의무보유에 관한 사항,  - 의무보유수량 : 6,310,679주,  - 의무보유기간 : '22.09.05 ~ '23.09.04", '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '6,310,679', '1,030', "제34회('22.08.13)"]
# ['1.회사명', '(주)노바렉스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A194700', '900,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '9,903,740', '2022-01-01', '5.상장일', '2022-09-01', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '900,000', '25,100', "제6회('22.08.19)"]
# ['1.회사명', '(주)코디엠', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A224060', '1,282,050', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '60,712,429', '2022-01-01', '5.상장일', '2022-08-26', '6.기타', '-', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,282,050', '780', "제20회('22.08.02)"]
# ['1.회사명', '(주)바이오로그디바이스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A208710', '823,045', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '42,254,457', '2022-01-01', '5.상장일', '2022-08-26', '6.기타', '-', '【발행내역】', '보통주', '유상증자(일반공모)', '일반공모', '823,045', '1,215', "제8회('22.08.13)"]
# ['1.회사명', '커머스마이너 주식회사', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A223310', '1,978,630', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '15,312,136', '2022-01-01', '5.상장일', '2022-08-22', '6.기타', 'ㅇ 의무보유 내역,  - 대상주식수 : 1,978,630주,  - 대상기간 : 2022.08.22 ~ 2023.08.21', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,978,630', '2,527', "제28회('22.08.03)"]
# ['1.회사명', '(주)아이윈플러스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A123010', '59,000,000', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '118,636,752', '2022-01-01', '5.상장일', '2022-08-10', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '59,000,000', '493', "제44회('22.07.30)"]
# ['1.회사명', '(주)폴라리스세원', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A234100', '10,000,000', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '43,481,747', '2022-01-01', '5.상장일', '2022-08-03', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '10,000,000', '1,575', "제9회('22.07.22)"]
# ['1.회사명', '(주)이엠텍', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A091120', '1,245,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '17,132,936', '2022-01-01', '5.상장일', '2022-08-02', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '1,245,000', '19,050', "제25회('22.07.20)"]
# ['1.회사명', '조광아이엘아이(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A044060', '428,922', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '16,277,739', '2022-01-01', '5.상장일', '2022-07-22', '6.기타', '-', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '428,922', '8,160', "제10회('22.07.09)"]
# ['1.회사명', '(주)유틸렉스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A263050', '7,000,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '23,473,596', '2022-01-01', '5.상장일', '2022-07-21', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '7,000,000', '7,370', "제29회('22.07.09)"]
# ['1.회사명', '이화전기공업(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A024810', '39,544,422', '3.1주당 액면가/자본금(원)', '200', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '123,008,045', '2022-01-01', '5.상장일', '2022-07-19', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주우선공모', '39,544,422', '955', "제42회('22.07.08)"]
# ['1.회사명', '(주)에코프로비엠', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A247540', '1,611,344', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '24,530,810', '2022-01-01', '5.상장일', '2022-07-07', '6.기타', '○ 의무보유 내역,   - 대상주식수 : 317,329,   - 대상기간 : 2022.07.07 ~ 2023.07.07', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '1,611,344', '387,600', "제15회('22.06.25)"]
# ['1.회사명', '씨에스베어링 주식회사', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A297090', '3,919,600', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '13,500,000', '2022-01-01', '5.상장일', '2022-07-01', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정', '3,919,600', '12,950', "제4회('22.06.18)"]
# ['1.회사명', '(주)유니트론텍', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A142210', '3,000,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '15,560,930', '2022-01-01', '5.상장일', '2022-06-30', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '3,000,000', '4,585', "제5회('22.06.17)"]
# ['1.회사명', '크루셜텍(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A114120', '2,000,000', '3.1주당 액면가/자본금(원)', '1,000', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '22,961,315', '2022-01-01', '5.상장일', '2022-06-24', '6.기타', 'ㅇ 의무보유에 관한 사항,  - 의무보유주식수 : 2,000,000주,  - 의무보유기간 : 2022.06.24 ~ 2023.06.23(1년)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '2,000,000', '1,000', "제20회('22.06.09)"]
# ['1.회사명', '(주)코이즈', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A121850', '3,000,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '19,614,175', '2022-01-01', '5.상장일', '2022-06-20', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '3,000,000', '2,835', "제13회('22.06.04)"]
# ['1.회사명', '(주)에스티큐브', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A052020', '11,500,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '42,075,903', '2022-01-01', '5.상장일', '2022-06-10', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '11,500,000', '4,140', "제27회('22.05.28)"]
# ['1.회사명', '(주)스카이이앤엠', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A131100', '14,582,575', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '26,833,204', '2021-07-01', '5.상장일', '2022-05-26', '6.기타', 'ㅇ 의무보유에 관한 사항,   - 대상주식수(대상기간) : 14,582,575주 (2022-05-26 ~ 2023-05-25)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '14,582,575', '2,743', "제37회('22.05.12)"]
# ['1.회사명', '주식회사 파라텍', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A033540', '540,248', '3.1주당 액면가/자본금(원)', '200', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '50,675,379', '2022-01-01', '5.상장일', '2022-05-25', '6.기타', '-', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '540,248', '1,851', "제11회('22.05.12)"]
# ['1.회사명', '(주)한탑', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A002680', '1,724,829', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '29,994,817', '2022-01-01', '5.상장일', '2022-05-24', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정', '1,724,829', '2,580', "제8회('22.05.13)"]
# ['1.회사명', '(주)에스엘바이오닉스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A214310', '1,529,850', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '9,412,581', '2022-01-01', '5.상장일', '2022-05-17', '6.기타', "* 의무보유에 관한 사항,  - 의무보유주식수 : 1,529,850주,  - 의무보유기간 : '22.05.17~'23.05.16(1년)", '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,529,850', '2,680', "제27회('22.04.28)"]
# ['1.회사명', '(주)다원시스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A068240', '3,000,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '34,630,519', '2022-01-01', '5.상장일', '2022-05-11', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '3,000,000', '22,850', "제13회('22.04.29)"]
# ['1.회사명', '(주)에스디시스템', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A121890', '1,538,460', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '11,147,660', '2022-01-01', '5.상장일', '2022-04-29', '6.기타', 'ㅇ의무보유에 관한 사항,  - 의무보유주식수 : 1,538,460주,  - 의무보유기간 : 2022.04.29 ~ 2023.04.28', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,538,460', '650', "제7회('22.04.12)"]
# ['1.회사명', '(주)드림씨아이에스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A223250', '266,666', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '5,925,720', '2022-01-01', '5.상장일', '2022-04-25', '6.기타', "ㅇ 의무보유에 관한 사항,  - 대상주식수 : 266,666주,  - 대상기간 :'22.04.25~`23.04.24", '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '266,666', '11,250', "제7회('22.03.29)"]
# ['1.회사명', '주식회사 맥스트', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A377030', '1,111,950', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '9,665,441', '2022-01-01', '5.상장일', '2022-04-26', '6.기타', '* 우리사주조합 의무예탁,   - 대상주식수 : 77,837주,   - 대상기간 : 2022.04.26 ~ 2023.04.25', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '1,111,950', '32,950', "제5회('22.04.14)"]
# ['1.회사명', '(주)인포마크', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A175140', '2,364,343', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '8,772,174', '2022-01-01', '5.상장일', '2022-04-21', '6.기타', 'ㅇ 의무보유 내역,  - 대상주식수 : 2,364,343,  - 대상기간 : 2022.04.21 ~ 2023.04.20', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '2,364,343', '5,160', "제11회('22.04.01)"]
# ['1.회사명', '(주)위지트', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A036090', '2,297,794', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '97,936,832', '2022-01-01', '5.상장일', '2022-04-21', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 2,297,794주,   - 대상기간 : 2022.04.21 ~ 2023.04.20', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '2,297,794', '1,088', "제28회('22.04.01)"]
# ['1.회사명', '(주)에치에프알', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A230240', '607,006', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '13,489,026', '2022-01-01', '5.상장일', '2022-04-20', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 607,006주,   - 대상기간 : 2022.04.20 ~ 2023.04.19', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '607,006', '27,600', "제8회('22.04.01)"]
# ['1.회사명', '주식회사 고바이오랩', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A348150', '544,960', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '16,815,519', '2022-01-01', '5.상장일', '2022-04-20', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 544,960주,   - 대상기간 : 2022.04.20 ~ 2023.04.19', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '544,960', '18,350', "제24회('22.04.07)"]
# ['1.회사명', '(주)키이스트', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A054780', '104,773', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '19,547,793', '2022-01-01', '5.상장일', '2022-04-15', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 104,773주,   - 대상기간 : 2022.04.15 ~ 2023.04.14', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '104,773', '12,466', "제32회('22.04.01)"]
# ['1.회사명', '(주)케이피엠테크', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A042040', '10,526,315', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '156,204,044', '2022-01-01', '5.상장일', '2022-04-15', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 10,526,315주,   - 대상기간 : 2022.04.15 ~ 2023.04.14', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '10,526,315', '950', "제27회('22.04.01)"]
# ['1.회사명', '(주)블리츠웨이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A369370', '3,603,605', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '39,219,171', '2022-01-01', '5.상장일', '2022-04-14', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 3,603,605주,   - 대상기간 : 2022.04.14 ~ 2023.04.13', '【발행내역】', '보통주', '유상증자(제3자배정)', '-', '3,603,605', '5,550', "제5회('22.03.26)"]
# ['1.회사명', '(주)코리아센터', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A290510', '29,916,303', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '106,116,940', '2022-01-01', '5.상장일', '2022-04-12', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 29,916,303주,   - 대상기간 : 2022.04.12 ~ 2023.04.11', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '29,916,303', '6,616', "제11회('22.03.26)"]
# ['1.회사명', '경남제약 주식회사', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A053950', '10,800,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '30,849,565', '2022-01-01', '5.상장일', '2022-03-30', '6.기타', 'ㅇ 의무보유 내역,  - 대상주식수 : 2,472,273주,  - 대상기간 : 2022.03.30~2023.3.29', '【발행내역】', '보통주', '유상증자(일반공모)', '주주배정 후 실권주 일반공모', '10,800,000', '2,540', "제23회('22.03.17)"]
# ['1.회사명', '주식회사샘코', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A263540', '2,800,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '5,735,747', '2022-01-01', '5.상장일', '2022-03-17', '6.기타', 'ㅇ 의무보유에 관한 사항,  - 대상주식수 : 2,800,000,  - 대상기간 : 2022.03.17 ~ 2023.03.16(1년)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '2,800,000', '500', "제14회('22.02.25)"]
# ['1.회사명', '(주)엔지켐생명과학', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A183490', '5,300,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '13,631,345', '2022-01-01', '5.상장일', '2022-03-21', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '5,300,000', '31,800', "제33회('22.03.03)"]
# ['1.회사명', '(주)클라우드에어', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A036170', '5,333,333', '3.1주당 액면가/자본금(원)', '1,000', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '61,365,626', '2022-01-01', '5.상장일', '2022-03-16', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 5,333,333주,   - 대상기간 : 2022.03.16~2023.03.15', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '5,333,333', '1,500', "제44회('22.02.26)"]
# ['1.회사명', '(주)디에이테크놀로지', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A196490', '631,407', '3.1주당 액면가/자본금(원)', '2,500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '24,686,321', '2022-01-01', '5.상장일', '2022-03-11', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 631,407주,   - 대상기간 : 2022.03.11~2023.03.10', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '631,407', '6,731', "제30회('22.02.23)"]
# ['1.회사명', '(주)포티스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A141020', '254', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '32,802,132', '2022-01-01', '5.상장일', '2022-03-08', '6.기타', '-', '【발행내역】', '보통주', '유상증자(출자전환)', '제3자배정', '254', '10,000', "제39회('22.02.03)"]
# ['1.회사명', '(주)포티스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A141020', '3,200,000', '보통주', 'A141020', '16,000,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '16,801,878', '2021-01-01', '보통주', '32,801,878', '2022-01-01', '5.상장일', '2022-03-04', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 16,000,000주,   - 대상기간 : 2022.03.04~2022.09.03ㅇ 의무보유내역,   - 대상주식수 : 3,200,000주,   - 대상기간 : 2022.03.04~2022.09.03', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '3,200,000', '500', "제37회('21.12.31)", '보통주', '유상증자(제3자배정)', '제3자배정', '16,000,000', '500', "제38회('22.01.27)"]
# ['1.회사명', '(주)대유', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A290380', '8,000,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '22,478,326', '2022-01-01', '5.상장일', '2022-03-04', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '8,000,000', '4,250', "제7회('22.02.19)"]
# ['1.회사명', '(주)포티스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A141020', '9,000,000', '보통주', 'A141020', '2,800,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '10,801,878', '2021-01-01', '보통주', '13,601,878', '2021-01-01', '5.상장일', '2022-02-25', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 2,800,000주,   - 대상기간 : 2022.02.25~2022.08.24ㅇ 의무보유내역,   - 대상주식수 : 9,000,000주,   - 대상기간 : 2022.02.25~2022.08.24', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '9,000,000', '500', "제35회('21.12.01)", '보통주', '유상증자(제3자배정)', '제3자배정', '2,800,000', '500', "제36회('21.12.21)"]
# ['1.회사명', '(주)포티스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A141020', '18,692,684', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '36,132,782', '2021-01-01', '5.상장일', '2022-02-25', '6.기타', '2021.11.19 회생법원의 회생계획인가에 따른 출자전환', '【발행내역】', '보통주', '유상증자(출자전환)', '제3자배정', '18,692,684', '500', "제33회('21.11.29)"]
# ['1.회사명', '(주)지어소프트', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A051160', '899,875', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '15,474,430', '2022-01-01', '5.상장일', '2022-02-18', '6.기타', 'o 의무보유 내역,   - 대상주식수 : 899,875  ,   - 대상기간 : 2022.02.18 ~ 2023.02.17', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '899,875', '16,669', "제19회('22.02.04)"]
# ['1.회사명', '(주)젬백스지오', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A041590', '23,020,257', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '116,491,806', '2022-01-01', '5.상장일', '2022-02-18', '6.기타', 'ㅇ 의무보유 내역 ,   - 대상주식수 : 23,020,257주,   - 대상기간 : 2022.02.18~2023.02.17', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '23,020,257', '1,086', "제39회('22.01.25)"]
# ['1.회사명', '(주)위지트', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A036090', '5,407,653', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '95,639,038', '2022-01-01', '5.상장일', '2022-02-16', '6.기타', 'ㅇ 의무보유 내역 ,   - 대상주식수 : 5,407,653주,   - 대상기간 : 2022.02.16~2023.02.15', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '5,407,653', '1,202', "제27회('22.01.27)"]
# ['1.회사명', '(주)초록뱀컴퍼니', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A052300', '19,779,210', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '109,886,871', '2022-01-01', '5.상장일', '2022-02-09', '6.기타', '-의무보유 내역, 대상주식수 : 19,779,210, 대상기간 : 2022-02-09 ~ 2023-02-08', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '19,779,210', '1,087', "제64회('22.01.21)"]
# ['1.회사명', '(주)아이엠', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A101390', '1,384,482', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '8,103,470', '2022-01-01', '5.상장일', '2022-02-04', '6.기타', 'ㅇ 의무보유에 관한 사항,  - 의무보유주식수 : 1,384,482주,  - 의무보유기간 : 2022.02.04 ~ 2022.02.03(1년)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,384,482', '5,800', "제17회('22.01.20)"]
# ['1.회사명', '(주)세영디앤씨', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A052190', '2,283,105', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '5,331,891', '2021-01-01', '5.상장일', '2022-02-04', '6.기타', 'ㅇ의무보유에 관한 사항,  - 의무보유주식수 : 2,283,105주,  - 의무보유기간 : 2022.02.04 ~ 2023.02.03, ', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '2,283,105', '657', "제30회('21.12.24)"]
# ['1.회사명', '(주)초록뱀미디어', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A047820', '1,783,167', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '216,827,028', '2022-01-01', '5.상장일', '2022-02-03', '6.기타', "ㅇ 의무보유내역,   - 대상주식수 : 1,783,167주,   - 대상기간 : '22.2.3~'23.2.2 (1년)", '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,783,167', '2,804', "제58회('22.01.18)"]
# ['1.회사명', '아이원스(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A114810', '3,849,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '29,352,174', '2022-01-01', '5.상장일', '2022-01-28', '6.기타', 'ㅇ 의무보유내역,   - 대상주식수 : 3,849,000주,   - 대상기간 : 2022.01.28~2023.01.27', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '3,849,000', '10,634', "제8회('22.01.15)"]
# ['1.회사명', '(주)레드로버', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A060300', '1,941,747', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '28,630,534', '2022-01-01', '5.상장일', '2022-01-28', '6.기타', 'ㅇ의무보유 내역 ,  - 대상주식수 : 1,941,747주 ,  - 대상기간 : 2022.01.28~2023.01.27', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,941,747', '515', "제40회('22.01.14)"]
# ['1.회사명', '(주)오리엔트정공', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A065500', '8,300,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '31,742,912', '2022-01-01', '5.상장일', '2022-01-28', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '8,300,000', '1,900', "제22회('22.01.15)"]
# ['1.회사명', '(주)자연과환경', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A043910', '19,500,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '81,293,968', '2022-01-01', '5.상장일', '2022-01-27', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정', '19,500,000', '966', "제34회('22.01.15)"]
# ['1.회사명', '(주)에스엘바이오닉스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A214310', '2,919,932', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '7,499,535', '2022-01-01', '5.상장일', '2022-01-27', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주우선공모', '2,919,932', '4,730', "제25회('22.01.18)"]
# ['1.회사명', '이오플로우(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A294090', '3,000,000', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '14,745,532', '2022-01-01', '5.상장일', '2022-01-26', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정', '3,000,000', '37,800', "제14회('22.01.15)"]
# ['1.회사명', '이오플로우(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A294090', '175,312', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '11,745,532', '2021-01-01', '5.상장일', '2022-01-20', '6.기타', 'ㅇ의무보유 내역 ,  - 대상주식수 : 175,312주 ,  - 대상기간 : 2022.01.20~2023.01.19', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '175,312', '52,575', "제15회('21.12.28)"]
# ['1.회사명', '(주)에이비프로바이오', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A195990', '7,159,904', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '260,035,730', '2021-01-01', '5.상장일', '2022-01-13', '6.기타', '○ 의무보유내역,  - 대상주식수 : 7,159,904주,  - 대상기간 : 2022.01.13 ~ 2023.01.12', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '7,159,904', '838', "제33회('21.12.25)"]
# ['1.회사명', '(주)드래곤플라이', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A030350', '3,344,481', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '36,378,495', '2021-01-01', '5.상장일', '2022-01-13', '6.기타', 'ㅇ 의무보유 내역 ,   - 대상주식수 : 3,344,481주,   - 대상기간 : 2022.01.13~2023.01.12', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '3,344,481', '2,990', "제35회('21.12.30)"]
# ['1.회사명', '차이나크리스탈신소재홀딩스', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A900250', '4,046,774', '3.1주당 액면가/자본금(USD)', '0.500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '71,830,626', '2021-01-01', '5.상장일', '2022-01-12', '6.기타', "ㅇ 의무보유에 관한 사항,  - 대상주식수 : 4,046,774주,  - 대상기간 :'22.01.12~'23.01.11 ", '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '4,046,774', '1,600', "제4회('21.12.20)"]
# ['1.회사명', '(주)액션스퀘어', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A205500', '4,231,312', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '45,754,696', '2021-01-01', '5.상장일', '2022-01-10', '6.기타', 'ㅇ 의무보유 내역 ,   - 대상주식수 : 4,231,312주(2022.01.10~2023.01.09)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '4,231,312', '7,090', "제25회('21.12.25)"]
# ['1.회사명', '씨비아이(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A013720', '3,027,557', '3.1주당 액면가/자본금(원)', '100', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '55,837,092', '2021-01-01', '5.상장일', '2022-01-10', '6.기타', 'ㅇ 의무보유 내역 ,   - 대상주식수 : 3,027,557주,   - 대상기간 : 2022.01.10~2023.01.09 (1년)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '3,027,557', '2,649', "제14회('21.12.21)"]
# ['1.회사명', '(주)코프라', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A126600', '3,623,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '24,738,634', '2021-01-01', '5.상장일', '2022-01-10', '6.기타', 'ㅇ 의무보유에 관한 사항,  - 의무보유주식수 : 3,623,000주,  - 의무보유기간 : 2022.01.10 ~ 2023.01.09(1년)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '3,623,000', '8,520', "제7회('21.12.23)"]
# ['1.회사명', '(주)수성이노베이션', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A084180', '602,409', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '57,412,638', '2021-01-01', '5.상장일', '2022-01-12', '6.기타', '-', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '602,409', '1,660', "제21회('21.12.24)"]
# ['1.회사명', '(주)에이치앤비디자인', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A227100', '5,077,398', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '9,951,797', '2021-01-01', '5.상장일', '2022-01-11', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주우선공모', '5,077,398', '6,910', "제21회('21.12.31)"]
# ['1.회사명', '에스트래픽 주식회사', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A234300', '2,800,000', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '23,626,160', '2021-01-01', '5.상장일', '2022-01-11', '6.기타', '-', '【발행내역】', '보통주', '유상증자(구주주배정)', '주주배정 후 실권주 일반공모', '2,800,000', '4,270', "제11회('21.12.28)"]
# ['1.회사명', '주식회사 디엠티', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A134580', '1,863,585', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '13,113,585', '2021-01-01', '5.상장일', '2022-01-06', '6.기타', "ㅇ 의무보유에 관한 사항,  - 대상주식수 : 1,863,585주,  - 대상기간 :'22.01.06~'23.01.05 , ", '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,863,585', '2,683', "제4회('21.12.24)"]
# ['1.회사명', '에이치엘비테라퓨틱스(주)', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A115450', '4,247,192', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '31,335,211', '2021-01-01', '5.상장일', '2022-01-05', '6.기타', 'ㅇ 의무보유에 관한 사항,  - 의무보유주식수 : 4,247,192주,  - 의무보유기간 : 2022.01.05 ~ 2023.01.04(1년)', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '4,247,192', '9,418', "제27회('21.11.17)"]
# ['1.회사명', '(주)홈캐스트', '2.추가주식의 종류와 수', '주권종류', '단축코드', '추가주식수(주)', '보통주', 'A064240', '1,943,256', '3.1주당 액면가/자본금(원)', '500', '4.추가상장 후 상장주식총수', '주권종류', '주식수(주)', '배당기산일', '보통주', '35,038,012', '2021-01-01', '5.상장일', '2022-01-05', '6.기타', '○의무보유 내역,   - 대상주식수 : 1,943,256주,   - 대상기간 : 2022.01.05~2023.01.04, ', '【발행내역】', '보통주', '유상증자(제3자배정)', '제3자배정', '1,943,256', '2,573', "제24회('21.12.22)"]
#
# Jobs Done
# check the result with .report_content

# %%
pd.set_option("display.max_rows", 500)
sample = test20.report_content.copy()
sample.head()

# %%
def preprocess_return(input_str):
    input_str = input_str.replace(":","").replace("주식의 종류와 수", "")
    input_str = re.sub("\(제[0-9]*회\)","", string=input_str)
    input_str = re.sub("제[0-9]*회","", string=input_str)
    input_str = input_str.replace(",","").replace("(신형)","").replace("-","").strip()
    return_lst = input_str.split("주 ")
    return_lst = [x.strip() for x in return_lst]
    return return_lst

def preprocess_price(input_str):
    input_str = re.sub("\(1주당 자본금:[0-9]+원\)","", input_str)
    input_str = re.sub("\(무액면\)","",input_str)
    input_str = input_str.replace(":","").replace("1주의 발행가액","")
    input_str = input_str.replace(",","")
    input_str = re.sub("\(액면가\d+원\)", "", string=input_str)
    input_str = re.sub("\(액면가 \d+원\)", "", string=input_str)
    input_str = re.sub("\(액면가  \d+원\)", "", string=input_str)

    input_str = input_str.replace("(1주당 자본금  무액면)", "")
    input_str = input_str.replace("(1주당 자본금0, )", "")
    input_str = input_str.replace("(액면가 USD 0.25)", "")
    input_str = input_str.replace("(액면금  무액면)", "")
    input_str = re.sub("기명식 보통주 [0-9]+주","", input_str)

    input_str = re.sub("\(제[0-9]+회\)","", string=input_str)
    input_str = re.sub("제[0-9]+회","", string=input_str).replace("-","").strip()
    return_lst = input_str.split("원")
    return return_lst

def preprocess_how(input_str):
    input_str = input_str.replace(":","").replace("증자방법","")
    input_str = re.sub("제[0-9]+회","",input_str)
    input_str = re.sub("및","",input_str)
    input_str = re.sub(",","",input_str)
    input_str = re.sub("[0-9]+주","",input_str).replace(" ","")
    return input_str

# %%
sample = test20.report_content.copy()
sample.head()

# %%
#print(test20.report_content.iloc[245,:]["임시리턴"])
#test20.report_content.iloc[245,:]["발행가(원)"]

# %%
#sample["발행가(원)"].apply(preprocess_price)

# %%
sample["임시리턴"] = sample["임시리턴"].apply(preprocess_return)
sample["발행가(원)"] = sample["발행가(원)"].apply(preprocess_price)
sample["발행방법"] = sample["발행방법"].apply(preprocess_how)

# %%
sample["주식종류"] = sample["임시리턴"].apply(lambda x: x[0])
sample["발행주식수"] = sample["임시리턴"].apply(lambda x: x[1])
sample["발행가(원)"] = sample["발행가(원)"].apply(lambda x: x[0])
sample = sample.drop("임시리턴", axis=1)

# %%
sample.head()

# %%
#sample.drop(8, inplace=True)

# %%
#sample.loc[129,"발행가(원)"] = "2414"
#sample.loc[129]

# %%
sample["발행가(원)"] = sample["발행가(원)"].astype("int64")
sample["발행주식수"] = sample["발행주식수"].str.replace("주","").astype("int64")
sample["발행금액"] = sample["발행가(원)"] * sample["발행주식수"]
sample.head()

# %%
sample

# %%
# 값 수정하는 과정
#sample.loc[256,:] = ["진흥기업",	"002780",	"2018-12-06"	,850,	"유상증자(제3자배정)",	"기명식 보통",	91476,	77754600]
sample.tail()

# %%
name = "유상증자_코스피_2020_2022.csv"

# %%
sample.to_csv("{}".format(name))
